# %% [markdown]
# # GAN
#
# gans are trained to be generative models. They consist of a generator, which

# %%
import torch 
import torchvision 
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST

mnist = MNIST(root='Mdata/',
             train= True, 
             transform = Compose([ToTensor(), Normalize(mean = (0.5,),std = (0.5,))]))

# %%
def denorm(x):
    out = (x+1)/2
    return out.clamp(0,1)

# %%
import matplotlib.pyplot as plt 
img = mnist[0][0]
img_norm = denorm(img)
print(img_norm.permute(1,2,0).shape)

plt.imshow(img_norm[0], cmap='gray')
# Out:
# torch.Size([28, 28, 1])

# %%
from torch.utils.data import DataLoader
batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %% [markdown]
# ## It seems we dont need train validation split for this! We use everything for training.
#
# Heck we dont even need to have labels! This is unsupervised.

# %%
for xb,yb in data_loader:
    print(xb.shape)
    break
# Out:
# torch.Size([100, 1, 28, 28])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Discriminator model
#
# This takes an input and simply classifies it as real or fake. Use a simple linear fully connected network!
# The leaky relu allows a small gradieent signal for negative values to be passed through. Makes the gradients from the discriminator flow stronger into the generator.
#
# the sigmoid gives a probability - of whether the image was real!

# %%
image_size = 28*28
hidden_size = 256

import torch.nn as nn 

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size,hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size,1),
    nn.Sigmoid()   # so that it becomes a probability! 
)

D.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=256, bias=True)
#   (1): LeakyReLU(negative_slope=0.2)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): LeakyReLU(negative_slope=0.2)
#   (4): Linear(in_features=256, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %% [markdown]
# ## Generative network
#
# The input to the generator is typically a vector or a matrix, which is used as a seed for generating an image. We will use a linear feedforward neural network with 3 layers. Output will be a vector of 784, which can be transformed into a 28*28 image.
#
# Relu has been found to work better for the generative network.
#
# Tanh is used because our real images were mapped to the range [-1,1], so we want our generator to generate the same format. Allows the model to learn more quickly and satuates the color space of the training distribution quicker.
#
# why `latent_size=64`? This determines how much freedom we have. This for the human face could be that one latent dimension corresponds to the eye color!

# %%
latent_size = 64
G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size,hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size,image_size),  # 256 to 784
    nn.Tanh()   # The activation we are using the final layer should map the values to -1 to 1. This can be achieved by tanh
)
G.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=64, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=256, out_features=784, bias=True)
#   (5): Tanh()
# )

# %%
G
# Out:
# Sequential(
#   (0): Linear(in_features=64, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=256, out_features=784, bias=True)
#   (5): Tanh()
# )

# %% [markdown]
# ## Lets try to generate a set of images.

# %%
y = G(torch.randn(2,latent_size).to(device))
y.shape
# Out:
# torch.Size([2, 784])

# %%
y.reshape(-1,28,28).shape
gen_imgs = denorm(y.reshape(-1,28,28).detach().cpu())
plt.imshow(gen_imgs[0], cmap = 'gray')

# %% [markdown]
# ## Discriminatyor Training
# The discriminator is a binary classification model, we can use the binary crossentropy to use as a loss function.
# * If the image is real and you predict a high probability then you get a low loss!
#
# In this case we are not interested in what the digit contains. We are interested in whether it is real or fake. so labels for real images are all ones, and fake images are all 0s. we do a batch of real then a batch of fake ones.
#
# `train_discriminator` does one step of training the discriminator, on a batch of images.

# %%
criterion = nn.BCELoss()
d_opt = torch.optim.Adam(D.parameters(), lr = 0.0002)
g_opt = torch.optim.Adam(G.parameters(), lr = 0.0002)

# %%
def reset_grad():
    d_opt.zero_grad()
    g_opt.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)
    
    # loss for real images 
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)  # We expect the discriminator to output 1s
    real_score = outputs   # These are the probabilities
    
    # loss for fakeimages 
    z = torch.randn(batch_size, latent_size).to(device)  # We generate 100  latent vectors and move them to device
    fake_images = G(z)     # When we put the latent vectors into the generator, we get 100 fake images
    outputs = D(fake_images)   # The discriminator will hopefully think they are 0 
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs
    # Combine the losses 
    d_loss = d_loss_real+ d_loss_fake
    
    reset_grad()
    
    d_loss.backward()
    d_opt.step()
    
    return d_loss, real_score, fake_score

# %% [markdown]
# ## Generator training
#
# Since the output of the generators are vectors, which can be transformed to images, it is not obvious how we can train the generator. This is where we implement a very elegant **trick**. We do know the output images are generated or fake, we can pass them into the discriminator, and compare the output of the discriminator with the ground truth (i.e. all fake). We can then use this to calculate the loss for the genrator.
#
# We use the discriminator as part of the loss function.
#
# We wish the discriminator to think all of the generated images are real, so labels of `[1,1,1,1,1...]` is desired. So, the loss function should be the cross entropy between the output and the desired labels, which is a list of ones.

# %%
z = torch.randn(batch_size, latent_size).to(device)
fake_images = G(z)
#D(fake_images)

# %%
def train_generator():
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size,1).to(device)
    g_loss = criterion(D(fake_images),labels) # This is the binary cross entropy. We wish the discriminator to be fooled
    
    # backprop and optimize
    
    reset_grad()
    g_loss.backward()
    g_opt.step()
    return g_loss, fake_images

# %% [markdown]
# ## Training!
#
# create the directory where we can save intermediate outputs to visually inspect the progress of the model

# %%
import os 
sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %%
from IPython.display import Image
from torchvision.utils import save_image

for images, _ in data_loader:
    images = images.reshape(images.size(0),1,28,28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'))
    break

# %% [markdown]
# ### Visualising the generated images before it is trained.

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)
print(batch_size, latent_size)
def save_fake_images(index):
    fake_images = G(sample_vectors)
    print(fake_images.shape)
    fake_images = fake_images.reshape(fake_images.size(0),1,28,28)
    fake_fname= 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)
save_fake_images(0)
Image(os.path.join(sample_dir,'fake_images-0000.png'))
# Out:
# 100 64
# torch.Size([100, 784])
# Saving fake_images-0000.png

# %%
def find_current_ite():
    current_ite = os.listdir(sample_dir)
    current_ite = [int(x[-8:-4]) for x in current_ite if "fake_images" in x]
    current_ite = max(current_ite)
    return current_ite

# %%
num_epochs = 10 
total_step = len(data_loader)
current = find_current_ite()
from tqdm import tqdm 
d_losses, g_losses, real_scores, fake_scores = [],[],[],[]
for epoch in range(num_epochs):
    for i, (images, _) in enumerate(tqdm(data_loader)):
        # load a batch and transform to vectors 
        images = images.reshape(batch_size, -1).to(device)
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()
        
        # inspect the losses 
        if (i+1) %200 ==0:
            d_losses.append(d_loss)
            g_losses.append(g_loss)
            real_scores.append(real_score.mean())
            fake_scores.append(fake_score.mean())
            print("Epoch %d / %d, step %d/%d, d_loss: %.4f, g_loss: %.4f, D(x): %.2f, D(g(z)): %.2f" %(epoch+1, num_epochs, i+1, total_step, 
                                                                                       d_loss, g_loss, real_score.mean(),
                                                                                                      fake_score.mean()))
    save_fake_images(epoch+current+1)
# Out:
#   0%|                                                                                          | 0/600 [00:00<?, ?it/s]
#   0%|▍                                                                                 | 3/600 [00:00<00:25, 23.32it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:24, 24.55it/s]
#   2%|█▏                                                                                | 9/600 [00:00<00:23, 25.39it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:22, 26.43it/s]
#   2%|██                                                                               | 15/600 [00:00<00:21, 27.13it/s]
#   3%|██▍                                                                              | 18/600 [00:00<00:21, 27.12it/s]
#   4%|██▊                                                                              | 21/600 [00:00<00:21, 26.64it/s]
#   4%|███▏                                                                             | 24/600 [00:00<00:21, 26.22it/s]
#   4%|███▋                                                                             | 27/600 [00:01<00:21, 26.76it/s]
#   5%|████                                                                             | 30/600 [00:01<00:21, 27.00it/s]
#   6%|████▍                                                                            | 33/600 [00:01<00:21, 26.39it/s]
#   6%|████▊                                                                            | 36/600 [00:01<00:22, 25.52it/s]
#   6%|█████▎                                                                           | 39/600 [00:01<00:21, 26.11it/s]
#   7%|█████▋                                                                           | 42/600 [00:01<00:21, 26.19it/s]
#   8%|██████                                                                           | 45/600 [00:01<00:21, 25.91it/s]
#   8%|██████▌                                                                          | 49/600 [00:01<00:19, 27.69it/s]
#   9%|███████▏                                                                         | 53/600 [00:01<00:18, 28.94it/s]
#   9%|███████▌                                                                         | 56/600 [00:02<00:18, 28.91it/s]
#  10%|███████▉                                                                         | 59/600 [00:02<00:18, 28.70it/s]
#  10%|████████▎                                                                        | 62/600 [00:02<00:18, 28.93it/s]
#  11%|████████▊                                                                        | 65/600 [00:02<00:18, 28.42it/s]
#  11%|█████████▏                                                                       | 68/600 [00:02<00:18, 28.33it/s]
#  12%|█████████▌                                                                       | 71/600 [00:02<00:18, 28.26it/s]
#  12%|█████████▉                                                                       | 74/600 [00:02<00:18, 28.62it/s]
#  13%|██████████▍                                                                      | 77/600 [00:02<00:18, 28.79it/s]
#  13%|██████████▊                                                                      | 80/600 [00:02<00:18, 28.75it/s]
#  14%|███████████▏                                                                     | 83/600 [00:03<00:18, 28.15it/s]
#  14%|███████████▌                                                                     | 86/600 [00:03<00:18, 28.30it/s]
#  15%|████████████                                                                     | 89/600 [00:03<00:17, 28.44it/s]
#  16%|████████████▌                                                                    | 93/600 [00:03<00:16, 30.41it/s]
#  16%|█████████████                                                                    | 97/600 [00:03<00:16, 30.85it/s]
#  17%|█████████████▍                                                                  | 101/600 [00:03<00:15, 31.43it/s]
#  18%|██████████████                                                                  | 105/600 [00:03<00:15, 31.70it/s]
#  18%|██████████████▌                                                                 | 109/600 [00:03<00:16, 30.59it/s]
#  19%|███████████████                                                                 | 113/600 [00:03<00:16, 29.64it/s]
#  19%|███████████████▍                                                                | 116/600 [00:04<00:16, 28.67it/s]
#  20%|███████████████▊                                                                | 119/600 [00:04<00:17, 28.26it/s]
#  20%|████████████████▎                                                               | 122/600 [00:04<00:17, 27.74it/s]
#  21%|████████████████▋                                                               | 125/600 [00:04<00:17, 27.93it/s]
#  21%|█████████████████                                                               | 128/600 [00:04<00:16, 27.83it/s]
#  22%|█████████████████▍                                                              | 131/600 [00:04<00:16, 27.99it/s]
#  22%|█████████████████▊                                                              | 134/600 [00:04<00:16, 28.30it/s]
#  23%|██████████████████▍                                                             | 138/600 [00:04<00:15, 29.34it/s]
#  24%|██████████████████▊                                                             | 141/600 [00:04<00:15, 29.47it/s]
#  24%|███████████████████▏                                                            | 144/600 [00:05<00:15, 29.05it/s]
#  24%|███████████████████▌                                                            | 147/600 [00:05<00:16, 27.84it/s]
#  25%|████████████████████                                                            | 150/600 [00:05<00:16, 28.08it/s]
#  26%|████████████████████▍                                                           | 153/600 [00:05<00:16, 27.73it/s]
#  26%|████████████████████▊                                                           | 156/600 [00:05<00:15, 27.89it/s]
#  26%|█████████████████████▏                                                          | 159/600 [00:05<00:15, 28.35it/s]
#  27%|█████████████████████▌                                                          | 162/600 [00:05<00:16, 27.20it/s]
#  28%|██████████████████████                                                          | 165/600 [00:05<00:15, 27.70it/s]
#  28%|██████████████████████▍                                                         | 168/600 [00:05<00:15, 28.09it/s]
#  28%|██████████████████████▊                                                         | 171/600 [00:06<00:15, 28.50it/s]
#  29%|███████████████████████▏                                                        | 174/600 [00:06<00:14, 28.54it/s]
#  30%|███████████████████████▌                                                        | 177/600 [00:06<00:15, 28.09it/s]
#  30%|████████████████████████                                                        | 180/600 [00:06<00:15, 27.87it/s]
#  31%|████████████████████████▌                                                       | 184/600 [00:06<00:14, 28.94it/s]
#  31%|████████████████████████▉                                                       | 187/600 [00:06<00:14, 28.29it/s]
#  32%|█████████████████████████▎                                                      | 190/600 [00:06<00:14, 28.23it/s]
#  32%|█████████████████████████▋                                                      | 193/600 [00:06<00:14, 28.52it/s]
#  33%|██████████████████████████▏                                                     | 196/600 [00:06<00:14, 27.85it/s]
#  33%|██████████████████████████▌                                                     | 199/600 [00:07<00:14, 27.90it/s]
#  34%|██████████████████████████▉                                                     | 202/600 [00:07<00:14, 27.24it/s]
# Epoch 1 / 10, step 200/600, d_loss: 0.6243, g_loss: 1.8228, D(x): 0.82, D(g(z)): 0.27
#  34%|███████████████████████████▎                                                    | 205/600 [00:07<00:14, 26.62it/s]
#  35%|███████████████████████████▋                                                    | 208/600 [00:07<00:15, 25.28it/s]
#  35%|████████████████████████████▎                                                   | 212/600 [00:07<00:14, 27.33it/s]
#  36%|████████████████████████████▋                                                   | 215/600 [00:07<00:14, 27.41it/s]
#  36%|█████████████████████████████                                                   | 218/600 [00:07<00:13, 27.92it/s]
#  37%|█████████████████████████████▍                                                  | 221/600 [00:07<00:13, 27.07it/s]
#  37%|█████████████████████████████▊                                                  | 224/600 [00:07<00:13, 27.68it/s]
#  38%|██████████████████████████████▎                                                 | 227/600 [00:08<00:13, 27.53it/s]
#  38%|██████████████████████████████▋                                                 | 230/600 [00:08<00:13, 27.09it/s]
#  39%|███████████████████████████████                                                 | 233/600 [00:08<00:13, 27.76it/s]
#  39%|███████████████████████████████▍                                                | 236/600 [00:08<00:12, 28.34it/s]
#  40%|███████████████████████████████▊                                                | 239/600 [00:08<00:12, 28.43it/s]
#  40%|████████████████████████████████▎                                               | 242/600 [00:08<00:12, 28.42it/s]
#  41%|████████████████████████████████▋                                               | 245/600 [00:08<00:12, 28.65it/s]
#  41%|█████████████████████████████████                                               | 248/600 [00:08<00:12, 28.24it/s]
#  42%|█████████████████████████████████▌                                              | 252/600 [00:08<00:11, 29.23it/s]
#  42%|██████████████████████████████████                                              | 255/600 [00:09<00:11, 28.97it/s]
#  43%|██████████████████████████████████▍                                             | 258/600 [00:09<00:11, 28.63it/s]
#  44%|██████████████████████████████████▊                                             | 261/600 [00:09<00:11, 28.76it/s]
#  44%|███████████████████████████████████▏                                            | 264/600 [00:09<00:11, 28.40it/s]
#  45%|███████████████████████████████████▋                                            | 268/600 [00:09<00:11, 29.28it/s]
#  45%|████████████████████████████████████▏                                           | 271/600 [00:09<00:11, 29.34it/s]
#  46%|████████████████████████████████████▌                                           | 274/600 [00:09<00:11, 28.83it/s]
#  46%|████████████████████████████████████▉                                           | 277/600 [00:09<00:11, 28.98it/s]
#  47%|█████████████████████████████████████▍                                          | 281/600 [00:09<00:10, 30.39it/s]
#  48%|██████████████████████████████████████                                          | 285/600 [00:10<00:10, 30.25it/s]
#  48%|██████████████████████████████████████▌                                         | 289/600 [00:10<00:10, 30.57it/s]
#  49%|███████████████████████████████████████                                         | 293/600 [00:10<00:10, 30.51it/s]
#  50%|███████████████████████████████████████▌                                        | 297/600 [00:10<00:09, 30.97it/s]
#  50%|████████████████████████████████████████▏                                       | 301/600 [00:10<00:09, 31.36it/s]
#  51%|████████████████████████████████████████▋                                       | 305/600 [00:10<00:09, 31.28it/s]
#  52%|█████████████████████████████████████████▏                                      | 309/600 [00:10<00:09, 31.37it/s]
#  52%|█████████████████████████████████████████▋                                      | 313/600 [00:10<00:09, 31.52it/s]
#  53%|██████████████████████████████████████████▎                                     | 317/600 [00:11<00:08, 31.76it/s]
#  54%|██████████████████████████████████████████▊                                     | 321/600 [00:11<00:08, 31.48it/s]
#  54%|███████████████████████████████████████████▎                                    | 325/600 [00:11<00:08, 31.73it/s]
#  55%|███████████████████████████████████████████▊                                    | 329/600 [00:11<00:08, 31.91it/s]
#  56%|████████████████████████████████████████████▍                                   | 333/600 [00:11<00:08, 31.89it/s]
#  56%|████████████████████████████████████████████▉                                   | 337/600 [00:11<00:08, 31.79it/s]
#  57%|█████████████████████████████████████████████▍                                  | 341/600 [00:11<00:08, 31.84it/s]
#  57%|██████████████████████████████████████████████                                  | 345/600 [00:11<00:07, 32.14it/s]
#  58%|██████████████████████████████████████████████▌                                 | 349/600 [00:12<00:07, 32.44it/s]
#  59%|███████████████████████████████████████████████                                 | 353/600 [00:12<00:07, 31.64it/s]
#  60%|███████████████████████████████████████████████▌                                | 357/600 [00:12<00:07, 31.70it/s]
#  60%|████████████████████████████████████████████████▏                               | 361/600 [00:12<00:07, 31.97it/s]
#  61%|████████████████████████████████████████████████▋                               | 365/600 [00:12<00:07, 32.47it/s]
#  62%|█████████████████████████████████████████████████▏                              | 369/600 [00:12<00:07, 32.55it/s]
#  62%|█████████████████████████████████████████████████▋                              | 373/600 [00:12<00:06, 32.52it/s]
#  63%|██████████████████████████████████████████████████▎                             | 377/600 [00:12<00:07, 31.85it/s]
#  64%|██████████████████████████████████████████████████▊                             | 381/600 [00:13<00:06, 32.62it/s]
#  64%|███████████████████████████████████████████████████▎                            | 385/600 [00:13<00:06, 32.41it/s]
#  65%|███████████████████████████████████████████████████▊                            | 389/600 [00:13<00:06, 32.04it/s]
#  66%|████████████████████████████████████████████████████▍                           | 393/600 [00:13<00:06, 32.60it/s]
#  66%|████████████████████████████████████████████████████▉                           | 397/600 [00:13<00:06, 32.92it/s]
#  67%|█████████████████████████████████████████████████████▍                          | 401/600 [00:13<00:06, 32.62it/s]
#  68%|██████████████████████████████████████████████████████                          | 405/600 [00:13<00:06, 31.25it/s]
# Epoch 1 / 10, step 400/600, d_loss: 0.7267, g_loss: 1.7057, D(x): 0.77, D(g(z)): 0.26
#  68%|██████████████████████████████████████████████████████▌                         | 409/600 [00:13<00:06, 29.65it/s]
#  69%|███████████████████████████████████████████████████████                         | 413/600 [00:14<00:06, 30.13it/s]
#  70%|███████████████████████████████████████████████████████▌                        | 417/600 [00:14<00:05, 30.73it/s]
#  70%|████████████████████████████████████████████████████████▏                       | 421/600 [00:14<00:05, 31.17it/s]
#  71%|████████████████████████████████████████████████████████▋                       | 425/600 [00:14<00:05, 31.97it/s]
#  72%|█████████████████████████████████████████████████████████▏                      | 429/600 [00:14<00:05, 32.55it/s]
#  72%|█████████████████████████████████████████████████████████▋                      | 433/600 [00:14<00:05, 32.61it/s]
#  73%|██████████████████████████████████████████████████████████▎                     | 437/600 [00:14<00:04, 32.93it/s]
#  74%|██████████████████████████████████████████████████████████▊                     | 441/600 [00:14<00:04, 32.91it/s]
#  74%|███████████████████████████████████████████████████████████▎                    | 445/600 [00:15<00:04, 32.51it/s]
#  75%|███████████████████████████████████████████████████████████▊                    | 449/600 [00:15<00:04, 32.42it/s]
#  76%|████████████████████████████████████████████████████████████▍                   | 453/600 [00:15<00:04, 32.27it/s]
#  76%|████████████████████████████████████████████████████████████▉                   | 457/600 [00:15<00:04, 32.55it/s]
#  77%|█████████████████████████████████████████████████████████████▍                  | 461/600 [00:15<00:05, 27.45it/s]
#  77%|█████████████████████████████████████████████████████████████▊                  | 464/600 [00:15<00:04, 27.27it/s]
#  78%|██████████████████████████████████████████████████████████████▎                 | 467/600 [00:15<00:04, 26.85it/s]
#  78%|██████████████████████████████████████████████████████████████▋                 | 470/600 [00:15<00:04, 26.29it/s]
#  79%|███████████████████████████████████████████████████████████████                 | 473/600 [00:16<00:04, 27.10it/s]
#  79%|███████████████████████████████████████████████████████████████▍                | 476/600 [00:16<00:04, 27.25it/s]
#  80%|████████████████████████████████████████████████████████████████                | 480/600 [00:16<00:04, 28.74it/s]
#  81%|████████████████████████████████████████████████████████████████▌               | 484/600 [00:16<00:03, 30.41it/s]
#  81%|█████████████████████████████████████████████████████████████████               | 488/600 [00:16<00:03, 30.87it/s]
#  82%|█████████████████████████████████████████████████████████████████▌              | 492/600 [00:16<00:03, 30.19it/s]
#  83%|██████████████████████████████████████████████████████████████████▏             | 496/600 [00:16<00:03, 28.51it/s]
#  83%|██████████████████████████████████████████████████████████████████▌             | 499/600 [00:16<00:03, 28.88it/s]
#  84%|███████████████████████████████████████████████████████████████████             | 503/600 [00:17<00:03, 30.00it/s]
#  84%|███████████████████████████████████████████████████████████████████▌            | 507/600 [00:17<00:03, 30.73it/s]
#  85%|████████████████████████████████████████████████████████████████████▏           | 511/600 [00:17<00:02, 31.34it/s]
#  86%|████████████████████████████████████████████████████████████████████▋           | 515/600 [00:17<00:02, 31.78it/s]
#  86%|█████████████████████████████████████████████████████████████████████▏          | 519/600 [00:17<00:02, 32.22it/s]
#  87%|█████████████████████████████████████████████████████████████████████▋          | 523/600 [00:17<00:02, 31.49it/s]
#  88%|██████████████████████████████████████████████████████████████████████▎         | 527/600 [00:17<00:02, 29.37it/s]
#  88%|██████████████████████████████████████████████████████████████████████▋         | 530/600 [00:17<00:02, 28.05it/s]
#  89%|███████████████████████████████████████████████████████████████████████         | 533/600 [00:18<00:02, 28.23it/s]
#  89%|███████████████████████████████████████████████████████████████████████▍        | 536/600 [00:18<00:02, 27.12it/s]
#  90%|███████████████████████████████████████████████████████████████████████▊        | 539/600 [00:18<00:02, 27.12it/s]
#  90%|████████████████████████████████████████████████████████████████████████▎       | 542/600 [00:18<00:02, 27.26it/s]
#  91%|████████████████████████████████████████████████████████████████████████▋       | 545/600 [00:18<00:02, 25.74it/s]
#  91%|█████████████████████████████████████████████████████████████████████████       | 548/600 [00:18<00:01, 26.02it/s]
#  92%|█████████████████████████████████████████████████████████████████████████▍      | 551/600 [00:18<00:01, 25.71it/s]
#  92%|█████████████████████████████████████████████████████████████████████████▊      | 554/600 [00:18<00:01, 26.42it/s]
#  93%|██████████████████████████████████████████████████████████████████████████▎     | 557/600 [00:18<00:01, 26.83it/s]
#  93%|██████████████████████████████████████████████████████████████████████████▋     | 560/600 [00:19<00:01, 27.26it/s]
#  94%|███████████████████████████████████████████████████████████████████████████     | 563/600 [00:19<00:01, 27.21it/s]
#  94%|███████████████████████████████████████████████████████████████████████████▌    | 567/600 [00:19<00:01, 28.57it/s]
#  95%|████████████████████████████████████████████████████████████████████████████    | 570/600 [00:19<00:01, 24.47it/s]
#  96%|████████████████████████████████████████████████████████████████████████████▍   | 573/600 [00:19<00:01, 25.40it/s]
#  96%|████████████████████████████████████████████████████████████████████████████▊   | 576/600 [00:19<00:00, 24.55it/s]
#  96%|█████████████████████████████████████████████████████████████████████████████▏  | 579/600 [00:19<00:00, 22.14it/s]
#  97%|█████████████████████████████████████████████████████████████████████████████▌  | 582/600 [00:19<00:00, 23.62it/s]
#  98%|██████████████████████████████████████████████████████████████████████████████▏ | 586/600 [00:20<00:00, 25.75it/s]
#  98%|██████████████████████████████████████████████████████████████████████████████▌ | 589/600 [00:20<00:00, 26.21it/s]
#  99%|██████████████████████████████████████████████████████████████████████████████▉ | 592/600 [00:20<00:00, 27.07it/s]
#  99%|███████████████████████████████████████████████████████████████████████████████▍| 596/600 [00:20<00:00, 29.11it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:20<00:00, 29.13it/s]
#
#   0%|                                                                                          | 0/600 [00:00<?, ?it/s]
#   0%|▎                                                                                 | 2/600 [00:00<00:30, 19.66it/s]
# Epoch 1 / 10, step 600/600, d_loss: 0.8541, g_loss: 2.2656, D(x): 0.68, D(g(z)): 0.16
# torch.Size([100, 784])
# Saving fake_images-0093.png
#   1%|▋                                                                                 | 5/600 [00:00<00:28, 20.95it/s]
#   1%|▉                                                                                 | 7/600 [00:00<00:29, 20.33it/s]
#   2%|█▎                                                                               | 10/600 [00:00<00:27, 21.67it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:29, 20.16it/s]
#   2%|██                                                                               | 15/600 [00:00<00:26, 21.98it/s]
#   3%|██▌                                                                              | 19/600 [00:00<00:23, 24.73it/s]
#   4%|███                                                                              | 23/600 [00:00<00:21, 26.29it/s]
#   4%|███▌                                                                             | 26/600 [00:01<00:22, 25.01it/s]
#   5%|███▉                                                                             | 29/600 [00:01<00:22, 25.15it/s]
#   5%|████▎                                                                            | 32/600 [00:01<00:22, 24.94it/s]
#   6%|████▋                                                                            | 35/600 [00:01<00:22, 25.45it/s]
#   6%|█████▏                                                                           | 38/600 [00:01<00:22, 25.33it/s]
#   7%|█████▌                                                                           | 41/600 [00:01<00:21, 26.00it/s]
#   7%|█████▉                                                                           | 44/600 [00:01<00:21, 25.64it/s]
#   8%|██████▎                                                                          | 47/600 [00:01<00:21, 25.98it/s]
#   8%|██████▊                                                                          | 50/600 [00:01<00:21, 26.10it/s]
#   9%|███████▏                                                                         | 53/600 [00:02<00:21, 25.57it/s]
#   9%|███████▌                                                                         | 56/600 [00:02<00:21, 25.81it/s]
#  10%|███████▉                                                                         | 59/600 [00:02<00:20, 26.88it/s]
#  10%|████████▎                                                                        | 62/600 [00:02<00:19, 27.39it/s]
#  11%|████████▊                                                                        | 65/600 [00:02<00:19, 27.63it/s]
#  11%|█████████▏                                                                       | 68/600 [00:02<00:18, 28.17it/s]
#  12%|█████████▌                                                                       | 71/600 [00:02<00:19, 27.46it/s]
#  12%|█████████▉                                                                       | 74/600 [00:02<00:20, 25.73it/s]
#  13%|██████████▍                                                                      | 77/600 [00:02<00:20, 25.66it/s]
#  13%|██████████▊                                                                      | 80/600 [00:03<00:19, 26.80it/s]
#  14%|███████████▏                                                                     | 83/600 [00:03<00:18, 27.41it/s]
#  14%|███████████▌                                                                     | 86/600 [00:03<00:19, 26.73it/s]
#  15%|████████████                                                                     | 89/600 [00:03<00:19, 26.70it/s]
#  15%|████████████▍                                                                    | 92/600 [00:03<00:19, 26.19it/s]
#  16%|████████████▊                                                                    | 95/600 [00:03<00:19, 25.32it/s]
#  16%|█████████████▏                                                                   | 98/600 [00:03<00:19, 26.03it/s]
#  17%|█████████████▍                                                                  | 101/600 [00:03<00:18, 26.78it/s]
#  17%|█████████████▊                                                                  | 104/600 [00:03<00:18, 26.87it/s]
#  18%|██████████████▎                                                                 | 107/600 [00:04<00:18, 26.68it/s]
#  18%|██████████████▋                                                                 | 110/600 [00:04<00:19, 25.15it/s]
#  19%|███████████████                                                                 | 113/600 [00:04<00:20, 23.81it/s]
#  19%|███████████████▍                                                                | 116/600 [00:04<00:19, 24.84it/s]
#  20%|███████████████▊                                                                | 119/600 [00:04<00:18, 25.60it/s]
#  20%|████████████████▎                                                               | 122/600 [00:04<00:18, 26.10it/s]
#  21%|████████████████▋                                                               | 125/600 [00:04<00:18, 26.25it/s]
#  21%|█████████████████                                                               | 128/600 [00:04<00:17, 26.36it/s]
#  22%|█████████████████▍                                                              | 131/600 [00:05<00:17, 26.10it/s]
#  22%|█████████████████▊                                                              | 134/600 [00:05<00:17, 26.15it/s]
#  23%|██████████████████▎                                                             | 137/600 [00:05<00:18, 24.85it/s]
#  23%|██████████████████▋                                                             | 140/600 [00:05<00:18, 24.58it/s]
#  24%|███████████████████                                                             | 143/600 [00:05<00:18, 25.22it/s]
#  24%|███████████████████▍                                                            | 146/600 [00:05<00:17, 26.06it/s]
#  25%|███████████████████▊                                                            | 149/600 [00:05<00:17, 26.47it/s]
#  25%|████████████████████▎                                                           | 152/600 [00:05<00:16, 26.51it/s]
#  26%|████████████████████▋                                                           | 155/600 [00:05<00:16, 26.62it/s]
#  26%|█████████████████████▏                                                          | 159/600 [00:06<00:15, 28.34it/s]
#  27%|█████████████████████▌                                                          | 162/600 [00:06<00:15, 28.76it/s]
#  28%|██████████████████████▏                                                         | 166/600 [00:06<00:14, 29.68it/s]
#  28%|██████████████████████▌                                                         | 169/600 [00:06<00:14, 29.62it/s]
#  29%|██████████████████████▉                                                         | 172/600 [00:06<00:15, 27.78it/s]
#  29%|███████████████████████▍                                                        | 176/600 [00:06<00:14, 29.14it/s]
#  30%|███████████████████████▊                                                        | 179/600 [00:06<00:14, 29.03it/s]
#  30%|████████████████████████▍                                                       | 183/600 [00:06<00:13, 30.25it/s]
#  31%|████████████████████████▉                                                       | 187/600 [00:07<00:13, 30.49it/s]
#  32%|█████████████████████████▍                                                      | 191/600 [00:07<00:13, 31.07it/s]
#  32%|██████████████████████████                                                      | 195/600 [00:07<00:13, 31.07it/s]
#  33%|██████████████████████████▌                                                     | 199/600 [00:07<00:13, 30.58it/s]
#  34%|███████████████████████████                                                     | 203/600 [00:07<00:13, 29.87it/s]
# Epoch 2 / 10, step 200/600, d_loss: 0.6106, g_loss: 2.2040, D(x): 0.80, D(g(z)): 0.21
#  34%|███████████████████████████▌                                                    | 207/600 [00:07<00:12, 30.50it/s]
#  35%|████████████████████████████▏                                                   | 211/600 [00:07<00:12, 30.47it/s]
#  36%|████████████████████████████▋                                                   | 215/600 [00:07<00:12, 31.45it/s]
#  36%|█████████████████████████████▏                                                  | 219/600 [00:08<00:11, 31.94it/s]
#  37%|█████████████████████████████▋                                                  | 223/600 [00:08<00:11, 31.45it/s]
#  38%|██████████████████████████████▎                                                 | 227/600 [00:08<00:12, 30.35it/s]
#  38%|██████████████████████████████▊                                                 | 231/600 [00:08<00:12, 30.29it/s]
#  39%|███████████████████████████████▎                                                | 235/600 [00:08<00:11, 30.88it/s]
#  40%|███████████████████████████████▊                                                | 239/600 [00:08<00:13, 25.90it/s]
#  40%|████████████████████████████████▍                                               | 243/600 [00:08<00:12, 27.81it/s]
#  41%|████████████████████████████████▊                                               | 246/600 [00:09<00:12, 28.33it/s]
#  42%|█████████████████████████████████▏                                              | 249/600 [00:09<00:13, 26.40it/s]
#  42%|█████████████████████████████████▌                                              | 252/600 [00:09<00:13, 25.65it/s]
#  42%|██████████████████████████████████                                              | 255/600 [00:09<00:13, 25.61it/s]
#  43%|██████████████████████████████████▍                                             | 258/600 [00:09<00:14, 24.10it/s]
#  44%|██████████████████████████████████▉                                             | 262/600 [00:09<00:12, 26.35it/s]
#  44%|███████████████████████████████████▎                                            | 265/600 [00:09<00:12, 25.95it/s]
#  45%|███████████████████████████████████▋                                            | 268/600 [00:09<00:13, 25.35it/s]
#  45%|████████████████████████████████████▎                                           | 272/600 [00:10<00:12, 27.06it/s]
#  46%|████████████████████████████████████▊                                           | 276/600 [00:10<00:11, 28.67it/s]
#  47%|█████████████████████████████████████▎                                          | 280/600 [00:10<00:10, 29.88it/s]
#  47%|█████████████████████████████████████▊                                          | 284/600 [00:10<00:10, 31.07it/s]
#  48%|██████████████████████████████████████▍                                         | 288/600 [00:10<00:10, 30.94it/s]
#  49%|██████████████████████████████████████▉                                         | 292/600 [00:10<00:09, 31.31it/s]
#  49%|███████████████████████████████████████▍                                        | 296/600 [00:10<00:09, 31.16it/s]
#  50%|████████████████████████████████████████                                        | 300/600 [00:10<00:09, 31.96it/s]
#  51%|████████████████████████████████████████▌                                       | 304/600 [00:10<00:09, 32.23it/s]
#  51%|█████████████████████████████████████████                                       | 308/600 [00:11<00:08, 32.58it/s]
#  52%|█████████████████████████████████████████▌                                      | 312/600 [00:11<00:08, 32.83it/s]
#  53%|██████████████████████████████████████████▏                                     | 316/600 [00:11<00:08, 32.68it/s]
#  53%|██████████████████████████████████████████▋                                     | 320/600 [00:11<00:10, 27.60it/s]
#  54%|███████████████████████████████████████████                                     | 323/600 [00:11<00:09, 28.18it/s]
#  54%|███████████████████████████████████████████▍                                    | 326/600 [00:11<00:09, 28.68it/s]
#  55%|████████████████████████████████████████████                                    | 330/600 [00:11<00:09, 29.82it/s]
#  56%|████████████████████████████████████████████▌                                   | 334/600 [00:12<00:09, 26.91it/s]
#  56%|████████████████████████████████████████████▉                                   | 337/600 [00:12<00:09, 27.18it/s]
#  57%|█████████████████████████████████████████████▎                                  | 340/600 [00:12<00:09, 27.72it/s]
#  57%|█████████████████████████████████████████████▊                                  | 344/600 [00:12<00:08, 28.93it/s]
#  58%|██████████████████████████████████████████████▎                                 | 347/600 [00:12<00:09, 27.92it/s]
#  58%|██████████████████████████████████████████████▊                                 | 351/600 [00:12<00:08, 29.18it/s]
#  59%|███████████████████████████████████████████████▏                                | 354/600 [00:12<00:08, 28.77it/s]
#  60%|███████████████████████████████████████████████▋                                | 358/600 [00:12<00:08, 29.95it/s]
#  60%|████████████████████████████████████████████████▎                               | 362/600 [00:12<00:07, 30.15it/s]
#  61%|████████████████████████████████████████████████▊                               | 366/600 [00:13<00:09, 25.72it/s]
#  62%|█████████████████████████████████████████████████▏                              | 369/600 [00:13<00:10, 22.29it/s]
#  62%|█████████████████████████████████████████████████▌                              | 372/600 [00:13<00:09, 23.22it/s]
#  63%|██████████████████████████████████████████████████▏                             | 376/600 [00:13<00:08, 25.76it/s]
#  63%|██████████████████████████████████████████████████▌                             | 379/600 [00:13<00:09, 24.19it/s]
#  64%|██████████████████████████████████████████████████▉                             | 382/600 [00:13<00:08, 24.87it/s]
#  64%|███████████████████████████████████████████████████▍                            | 386/600 [00:13<00:07, 27.16it/s]
#  65%|████████████████████████████████████████████████████                            | 390/600 [00:14<00:07, 28.87it/s]
#  66%|████████████████████████████████████████████████████▌                           | 394/600 [00:14<00:06, 29.66it/s]
#  66%|█████████████████████████████████████████████████████                           | 398/600 [00:14<00:06, 30.59it/s]
#  67%|█████████████████████████████████████████████████████▌                          | 402/600 [00:14<00:06, 30.36it/s]
# Epoch 2 / 10, step 400/600, d_loss: 0.7726, g_loss: 1.9308, D(x): 0.70, D(g(z)): 0.21
#  68%|██████████████████████████████████████████████████████▏                         | 406/600 [00:14<00:06, 31.14it/s]
#  68%|██████████████████████████████████████████████████████▋                         | 410/600 [00:14<00:06, 31.05it/s]
#  69%|███████████████████████████████████████████████████████▏                        | 414/600 [00:14<00:05, 31.96it/s]
#  70%|███████████████████████████████████████████████████████▋                        | 418/600 [00:14<00:05, 32.38it/s]
#  70%|████████████████████████████████████████████████████████▎                       | 422/600 [00:15<00:05, 32.61it/s]
#  71%|████████████████████████████████████████████████████████▊                       | 426/600 [00:15<00:05, 32.85it/s]
#  72%|█████████████████████████████████████████████████████████▎                      | 430/600 [00:15<00:05, 33.22it/s]
#  72%|█████████████████████████████████████████████████████████▊                      | 434/600 [00:15<00:05, 31.70it/s]
#  73%|██████████████████████████████████████████████████████████▍                     | 438/600 [00:15<00:05, 31.97it/s]
#  74%|██████████████████████████████████████████████████████████▉                     | 442/600 [00:15<00:04, 32.55it/s]
#  74%|███████████████████████████████████████████████████████████▍                    | 446/600 [00:15<00:04, 33.01it/s]
#  75%|████████████████████████████████████████████████████████████                    | 450/600 [00:15<00:04, 32.92it/s]
#  76%|████████████████████████████████████████████████████████████▌                   | 454/600 [00:16<00:04, 33.27it/s]
#  76%|█████████████████████████████████████████████████████████████                   | 458/600 [00:16<00:04, 33.57it/s]
#  77%|█████████████████████████████████████████████████████████████▌                  | 462/600 [00:16<00:04, 33.69it/s]
#  78%|██████████████████████████████████████████████████████████████▏                 | 466/600 [00:16<00:03, 33.87it/s]
#  78%|██████████████████████████████████████████████████████████████▋                 | 470/600 [00:16<00:03, 33.48it/s]
#  79%|███████████████████████████████████████████████████████████████▏                | 474/600 [00:16<00:03, 33.63it/s]
#  80%|███████████████████████████████████████████████████████████████▋                | 478/600 [00:16<00:03, 33.91it/s]
#  80%|████████████████████████████████████████████████████████████████▎               | 482/600 [00:16<00:03, 33.30it/s]
#  81%|████████████████████████████████████████████████████████████████▊               | 486/600 [00:17<00:03, 33.67it/s]
#  82%|█████████████████████████████████████████████████████████████████▎              | 490/600 [00:17<00:03, 33.84it/s]
#  82%|█████████████████████████████████████████████████████████████████▊              | 494/600 [00:17<00:03, 34.08it/s]
#  83%|██████████████████████████████████████████████████████████████████▍             | 498/600 [00:17<00:03, 33.89it/s]
#  84%|██████████████████████████████████████████████████████████████████▉             | 502/600 [00:17<00:02, 33.58it/s]
#  84%|███████████████████████████████████████████████████████████████████▍            | 506/600 [00:17<00:02, 33.65it/s]
#  85%|████████████████████████████████████████████████████████████████████            | 510/600 [00:17<00:02, 33.21it/s]
#  86%|████████████████████████████████████████████████████████████████████▌           | 514/600 [00:17<00:02, 33.56it/s]
#  86%|█████████████████████████████████████████████████████████████████████           | 518/600 [00:17<00:02, 33.78it/s]
#  87%|█████████████████████████████████████████████████████████████████████▌          | 522/600 [00:18<00:02, 33.84it/s]
#  88%|██████████████████████████████████████████████████████████████████████▏         | 526/600 [00:18<00:02, 34.05it/s]
#  88%|██████████████████████████████████████████████████████████████████████▋         | 530/600 [00:18<00:02, 33.95it/s]
#  89%|███████████████████████████████████████████████████████████████████████▏        | 534/600 [00:18<00:01, 33.88it/s]
#  90%|███████████████████████████████████████████████████████████████████████▋        | 538/600 [00:18<00:01, 32.83it/s]
#  90%|████████████████████████████████████████████████████████████████████████▎       | 542/600 [00:18<00:01, 33.00it/s]
#  91%|████████████████████████████████████████████████████████████████████████▊       | 546/600 [00:18<00:01, 33.00it/s]
#  92%|█████████████████████████████████████████████████████████████████████████▎      | 550/600 [00:18<00:01, 33.21it/s]
#  92%|█████████████████████████████████████████████████████████████████████████▊      | 554/600 [00:19<00:01, 32.62it/s]
#  93%|██████████████████████████████████████████████████████████████████████████▍     | 558/600 [00:19<00:01, 33.43it/s]
#  94%|██████████████████████████████████████████████████████████████████████████▉     | 562/600 [00:19<00:01, 33.26it/s]
#  94%|███████████████████████████████████████████████████████████████████████████▍    | 566/600 [00:19<00:01, 33.39it/s]
#  95%|████████████████████████████████████████████████████████████████████████████    | 570/600 [00:19<00:00, 32.67it/s]
#  96%|████████████████████████████████████████████████████████████████████████████▌   | 574/600 [00:19<00:00, 32.89it/s]
#  96%|█████████████████████████████████████████████████████████████████████████████   | 578/600 [00:19<00:00, 32.49it/s]
#  97%|█████████████████████████████████████████████████████████████████████████████▌  | 582/600 [00:19<00:00, 32.76it/s]
#  98%|██████████████████████████████████████████████████████████████████████████████▏ | 586/600 [00:20<00:00, 32.72it/s]
#  98%|██████████████████████████████████████████████████████████████████████████████▋ | 590/600 [00:20<00:00, 32.64it/s]
#  99%|███████████████████████████████████████████████████████████████████████████████▏| 594/600 [00:20<00:00, 32.67it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:20<00:00, 29.34it/s]
#
#   0%|                                                                                          | 0/600 [00:00<?, ?it/s]
#   0%|▍                                                                                 | 3/600 [00:00<00:20, 29.78it/s]
# Epoch 2 / 10, step 600/600, d_loss: 0.8632, g_loss: 1.9257, D(x): 0.69, D(g(z)): 0.27
# torch.Size([100, 784])
# Saving fake_images-0094.png
#   1%|▊                                                                                 | 6/600 [00:00<00:20, 29.09it/s]
#   2%|█▎                                                                               | 10/600 [00:00<00:18, 31.19it/s]
#   2%|█▉                                                                               | 14/600 [00:00<00:18, 32.36it/s]
#   3%|██▍                                                                              | 18/600 [00:00<00:17, 32.87it/s]
#   4%|██▉                                                                              | 22/600 [00:00<00:17, 33.20it/s]
#   4%|███▌                                                                             | 26/600 [00:00<00:17, 33.52it/s]
#   5%|████                                                                             | 30/600 [00:00<00:17, 32.67it/s]
#   6%|████▌                                                                            | 34/600 [00:01<00:17, 31.49it/s]
#   6%|█████▏                                                                           | 38/600 [00:01<00:17, 31.97it/s]
#   7%|█████▋                                                                           | 42/600 [00:01<00:17, 32.08it/s]
#   8%|██████▏                                                                          | 46/600 [00:01<00:17, 31.97it/s]
#   8%|██████▊                                                                          | 50/600 [00:01<00:17, 30.88it/s]
#   9%|███████▎                                                                         | 54/600 [00:01<00:18, 30.17it/s]
#  10%|███████▊                                                                         | 58/600 [00:01<00:18, 29.96it/s]
#  10%|████████▎                                                                        | 62/600 [00:01<00:17, 31.06it/s]
#  11%|████████▉                                                                        | 66/600 [00:02<00:16, 31.44it/s]
#  12%|█████████▍                                                                       | 70/600 [00:02<00:16, 32.24it/s]
#  12%|█████████▉                                                                       | 74/600 [00:02<00:16, 32.86it/s]
#  13%|██████████▌                                                                      | 78/600 [00:02<00:15, 33.61it/s]
#  14%|███████████                                                                      | 82/600 [00:02<00:15, 33.72it/s]
#  14%|███████████▌                                                                     | 86/600 [00:02<00:15, 33.89it/s]
#  15%|████████████▏                                                                    | 90/600 [00:02<00:14, 34.09it/s]
#  16%|████████████▋                                                                    | 94/600 [00:02<00:14, 33.89it/s]
#  16%|█████████████▏                                                                   | 98/600 [00:03<00:15, 32.28it/s]
#  17%|█████████████▌                                                                  | 102/600 [00:03<00:15, 32.30it/s]
#  18%|██████████████▏                                                                 | 106/600 [00:03<00:15, 32.47it/s]
#  18%|██████████████▋                                                                 | 110/600 [00:03<00:14, 32.75it/s]
#  19%|███████████████▏                                                                | 114/600 [00:03<00:14, 33.28it/s]
#  20%|███████████████▋                                                                | 118/600 [00:03<00:14, 33.28it/s]
#  20%|████████████████▎                                                               | 122/600 [00:03<00:14, 33.61it/s]
#  21%|████████████████▊                                                               | 126/600 [00:03<00:14, 32.89it/s]
#  22%|█████████████████▎                                                              | 130/600 [00:04<00:22, 20.60it/s]
#  22%|█████████████████▋                                                              | 133/600 [00:04<00:21, 21.86it/s]
#  23%|██████████████████▏                                                             | 136/600 [00:04<00:20, 23.15it/s]
#  23%|██████████████████▋                                                             | 140/600 [00:04<00:18, 25.50it/s]
#  24%|███████████████████                                                             | 143/600 [00:04<00:17, 26.58it/s]
#  24%|███████████████████▍                                                            | 146/600 [00:04<00:20, 22.56it/s]
#  25%|███████████████████▊                                                            | 149/600 [00:04<00:19, 23.61it/s]
#  26%|████████████████████▍                                                           | 153/600 [00:05<00:17, 25.64it/s]
#  26%|████████████████████▊                                                           | 156/600 [00:05<00:20, 22.15it/s]
#  27%|█████████████████████▎                                                          | 160/600 [00:05<00:17, 24.66it/s]
#  27%|█████████████████████▊                                                          | 164/600 [00:05<00:16, 26.45it/s]
#  28%|██████████████████████▎                                                         | 167/600 [00:05<00:15, 27.22it/s]
#  28%|██████████████████████▋                                                         | 170/600 [00:05<00:15, 27.86it/s]
#  29%|███████████████████████                                                         | 173/600 [00:05<00:15, 27.40it/s]
#  30%|███████████████████████▌                                                        | 177/600 [00:05<00:14, 28.97it/s]
#  30%|████████████████████████                                                        | 180/600 [00:06<00:14, 28.06it/s]
#  31%|████████████████████████▌                                                       | 184/600 [00:06<00:14, 29.48it/s]
#  31%|█████████████████████████                                                       | 188/600 [00:06<00:13, 30.01it/s]
#  32%|█████████████████████████▌                                                      | 192/600 [00:06<00:13, 31.03it/s]
#  33%|██████████████████████████▏                                                     | 196/600 [00:06<00:13, 29.94it/s]
#  33%|██████████████████████████▋                                                     | 200/600 [00:06<00:14, 27.11it/s]
#  34%|███████████████████████████▏                                                    | 204/600 [00:06<00:13, 28.70it/s]
# Epoch 3 / 10, step 200/600, d_loss: 0.8105, g_loss: 1.6699, D(x): 0.78, D(g(z)): 0.32
#  34%|███████████████████████████▌                                                    | 207/600 [00:07<00:13, 28.31it/s]
#  35%|████████████████████████████                                                    | 210/600 [00:07<00:13, 28.29it/s]
#  36%|████████████████████████████▌                                                   | 214/600 [00:07<00:12, 29.79it/s]
#  36%|█████████████████████████████                                                   | 218/600 [00:07<00:12, 31.01it/s]
#  37%|█████████████████████████████▌                                                  | 222/600 [00:07<00:11, 31.92it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-e100760791ac> in <module>()
#       8         # load a batch and transform to vectors
#       9         images = images.reshape(batch_size, -1).to(device)
# ---> 10         d_loss, real_score, fake_score = train_discriminator(images)
#      11         g_loss, fake_images = train_generator()
#      12
#
# <ipython-input-58-d29b623f4ddd> in train_discriminator(images)
#      26
#      27     d_loss.backward()
# ---> 28     d_opt.step()
#      29
#      30     return d_loss, real_score, fake_score
#
# c:\users\andy cai\appdata\local\programs\python\python36\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# c:\users\andy cai\appdata\local\programs\python\python36\lib\site-packages\torch\optim\adam.py in step(self, closure)
#     117                    group['lr'],
#     118                    group['weight_decay'],
# --> 119                    group['eps']
#     120                    )
#     121         return loss
#
# c:\users\andy cai\appdata\local\programs\python\python36\lib\site-packages\torch\optim\functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      92             denom = (max_exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(eps)
#      93         else:
# ---> 94             denom = (exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(eps)
#      95
#      96         step_size = lr / bias_correction1
#
# KeyboardInterrupt:
#  37%|█████████████████████████████▌                                                  | 222/600 [00:21<00:11, 31.92it/s]

# %% [markdown]
# ## Visualising the results
#
# It will be nice to actually visualise the progress using a video.

# %%
import cv2 
import os 
from IPython.display.display import FileLink
vid_fname = 'gans_training.avi'
files = [os.path.join(sample_dios.listdirfor f in os.listdfake_imagesmagesple_dir) if 'fake_images' in f]
files.sort()
out = cv2.VideoWriter(vid_fname, cv2.VideoWriter_fourcc(*'MP4V'), 8, (302,302))  # 8 images per second. (302,302) is the combined size of the images
[out.write(cv2.imread(fname)) for fname in files]
out.release()
FileLink('gans_training.avi')

# %%
torch.save(D.state_dict, "gan_linear_d1.pth")
torch.save(G.state_dict, 'gan_linear_g1.pth')
